# %% [markdown]
# # User story

# %%
# %load_ext autoreload
# %autoreload 2

import elliptio as eio
from pprint import pprint
from datetime import datetime, UTC, timedelta
import pandas as pd
from pathlib import Path
import git

pd.set_option('display.max_colwidth', None)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
class DummyModel:
    def train(self, train_path: Path):
        del train_path
        pass

    def save(self, url: Path):
        Path(url).write_text("dummy_model")

# %%
repo_path = Path(git.Repo(search_parent_directories=True).working_dir)

# %% [markdown]
# ## Save files

# %% [markdown]
# Andy is an ambitious data scientist who analyzes data and trains models. He just prepared a new `train.txt` and `test.txt` with a special stratification method. He saves them with the following API call:

# %%
h = eio.Handler(remote_file_cls=eio.LocalFile)

with eio.mock_username("andy"):
    artifact = h.upload(
        local_paths=[
            repo_path / "docs/train.txt",
            repo_path / "docs/test.txt",
        ],
        labels=eio.Labels(
            ticket="AB-123",
            project="awesome-project",
            datatype="annotation_file",
            infos={"stratification": "new special method"},
        ),
    )

# %% [markdown]
# Note that he doesn't need to specify the destination. The destination path is generated automatically and the S3 bucket is defined as an environment variable. The labels are optional.

# %% [markdown]
# ## Searching files by metadata

# %% [markdown]
# Brenda wants to use the files from Andy. However, Andy just started his Antartica-crossing last week and hasn't told anybody where he stored his work. So Brenda searches artifacts which were...
#
# - generated by Andy
# - labeled with `datatype=annotation_file`
# - generated within the last 10 days
# - contain `*.txt` files

# %%
df= h.find(
    query = {
        "username": "andy",
        "labels.datatype": "annotation_file",
        "creation_time": {"$gte": datetime.now(tz=UTC) - timedelta(days=7)},
        "file_relpaths": {"$regex": "\.txt"},
    },
    max_docs=1,
)
df
# Out:
#                                                         creation_time  \
# artifact_id
# artifact_b4c31f3a-c25d-4dda-aa74-cab7245116f8 2023-12-03 13:42:55.338
#
#                                               username          file_relpaths  \
# artifact_id
# artifact_b4c31f3a-c25d-4dda-aa74-cab7245116f8     andy  [train.txt, test.txt]
#
#                                                                                                                                                                                      argv  \
# artifact_id
# artifact_b4c31f3a-c25d-4dda-aa74-cab7245116f8  /home/cgebbe/venvs/elliptio/bin/python -m ipykernel_launcher --f=/home/cgebbe/.local/share/jupyter/runtime/kernel-v2-3296HzpU9aTlH5J3.json
#
#                                               based_on hostname  \
# artifact_id
# artifact_b4c31f3a-c25d-4dda-aa74-cab7245116f8       []   cgebbe
#
#                                                                                                                                                                                                             labels  \
# artifact_id
# artifact_b4c31f3a-c25d-4dda-aa74-cab7245116f8  {'datatype': 'annotation_file', 'ticket': 'AB-123', 'project': 'awesome-project', 'dataset': '', 'description': '', 'infos': {'stratification': 'new cool method'}}
#
#                                               local_root log_relpaths  \
# artifact_id
# artifact_b4c31f3a-c25d-4dda-aa74-cab7245116f8                      []
#
#                                                                                                                                   remote_root  \
# artifact_id
# artifact_b4c31f3a-c25d-4dda-aa74-cab7245116f8  /home/cgebbe/tmp/elliptio/2023/12/03/andy/134255_artifact_b4c31f3a-c25d-4dda-aa74-cab7245116f8
#
#                                                                                  run_id  \
# artifact_id
# artifact_b4c31f3a-c25d-4dda-aa74-cab7245116f8  run_2ea13cb6-61b9-41ef-82f7-b58acf119180
#
#                                                version
# artifact_id
# artifact_b4c31f3a-c25d-4dda-aa74-cab7245116f8        1

# %% [markdown]
# Based on the displayed results, Brenda is pretty sure she found the correct files. She notes down the unique `artifact_id`.

# %% [markdown]
# ## Using files

# %% [markdown]
# To use the file, Brenda uses the unique artifact ID and runs:

# %%
artifact_id = df.index[0]
artifact = h.get(artifact_id)
pprint(artifact)
pd.read_csv(artifact.files["test.txt"].remote_url)

# She could have also downloaded the file
# artifact.files["test.txt"].download()
# artifact.files["test.txt"].download_string()
# Out:
# Artifact(metadata=Metadata(username='andy',
#                            hostname='cgebbe',
#                            argv='/home/cgebbe/venvs/elliptio/bin/python -m '
#                                 'ipykernel_launcher '
#                                 '--f=/home/cgebbe/.local/share/jupyter/runtime/kernel-v2-3296HzpU9aTlH5J3.json',
#                            artifact_id='artifact_b4c31f3a-c25d-4dda-aa74-cab7245116f8',
#                            run_id='run_2ea13cb6-61b9-41ef-82f7-b58acf119180',
#                            creation_time=datetime.datetime(2023, 12, 3, 13, 42, 55, 338000),
#                            python_packages={'GitPython': '3.1.40',
#                                             'PyYAML': '6.0.1',
#                                             'Pygments': '2.16.1',
#                                             'assertpy': '1.1',
#                                             'asttokens': '2.4.1',
#                                             'black': '23.10.1',
#                                             'blessed': '1.20.0',
#                                             'boto3': '1.28.78',
#                                             'boto3-stubs': '1.28.78',
#                                             'botocore': '1.31.78',
#                                             'botocore-stubs': '1.31.78',
#                                             'bpython': '0.24',
#                                             'certifi': '2023.7.22',
#                                             'cfgv': '3.4.0',
#                                             'charset-normalizer': '3.3.2',
#                                             'click': '8.1.7',
#                                             'comm': '0.1.4',
#                                             'curtsies': '0.4.2',
#                                             'cwcwidth': '0.1.9',
#                                             'debugpy': '1.8.0',
#                                             'decorator': '5.1.1',
#                                             'distlib': '0.3.7',
#                                             'dnspython': '2.4.2',
#                                             'docopt': '0.6.2',
#                                             'elliptio': '0.0.0',
#                                             'executing': '2.0.1',
#                                             'filelock': '3.13.1',
#                                             'gitdb': '4.0.11',
#                                             'greenlet': '3.0.1',
#                                             'identify': '2.5.31',
#                                             'idna': '3.4',
#                                             'iniconfig': '2.0.0',
#                                             'invoke': '2.2.0',
#                                             'ipykernel': '6.26.0',
#                                             'ipython': '8.17.2',
#                                             'jedi': '0.19.1',
#                                             'jmespath': '1.0.1',
#                                             'jupyter_client': '8.5.0',
#                                             'jupyter_core': '5.5.0',
#                                             'matplotlib-inline': '0.1.6',
#                                             'mongomock': '4.1.2',
#                                             'mypy': '1.7.0',
#                                             'mypy-boto3-cloudformation': '1.28.64',
#                                             'mypy-boto3-dynamodb': '1.28.73',
#                                             'mypy-boto3-ec2': '1.28.75',
#                                             'mypy-boto3-lambda': '1.28.63',
#                                             'mypy-boto3-rds': '1.28.76',
#                                             'mypy-boto3-s3': '1.28.55',
#                                             'mypy-boto3-sqs': '1.28.36',
#                                             'mypy-boto3-ssm': '1.28.68',
#                                             'mypy-extensions': '1.0.0',
#                                             'nest-asyncio': '1.5.8',
#                                             'nodeenv': '1.8.0',
#                                             'numpy': '1.26.2',
#                                             'packaging': '23.2',
#                                             'pandas': '2.1.3',
#                                             'pandas-stubs': '2.1.1.230928',
#                                             'parso': '0.8.3',
#                                             'pathspec': '0.11.2',
#                                             'pexpect': '4.8.0',
#                                             'pip': '23.2.1',
#                                             'pipreqs': '0.4.13',
#                                             'platformdirs': '3.11.0',
#                                             'pluggy': '1.3.0',
#                                             'pre-commit': '3.5.0',
#                                             'prompt-toolkit': '3.0.39',
#                                             'psutil': '5.9.6',
#                                             'ptyprocess': '0.7.0',
#                                             'pudb': '2023.1',
#                                             'pure-eval': '0.2.2',
#                                             'pymongo': '4.6.0',
#                                             'pytest': '7.4.3',
#                                             'pytest-pudb': '0.7.0',
#                                             'python-dateutil': '2.8.2',
#                                             'python-dotenv': '1.0.0',
#                                             'pytz': '2023.3.post1',
#                                             'pyxdg': '0.28',
#                                             'pyzmq': '25.1.1',
#                                             'requests': '2.31.0',
#                                             'ruff': '0.1.4',
#                                             's3transfer': '0.7.0',
#                                             'sentinels': '1.0.0',
#                                             'setuptools': '65.5.0',
#                                             'six': '1.16.0',
#                                             'smmap': '5.0.1',
#                                             'stack-data': '0.6.3',
#                                             'toolz': '0.12.0',
#                                             'tornado': '6.3.3',
#                                             'traitlets': '5.13.0',
#                                             'types-PyYAML': '6.0.12.12',
#                                             'types-awscrt': '0.19.8',
#                                             'types-pytz': '2023.3.1.1',
#                                             'types-s3transfer': '0.7.0',
#                                             'typing_extensions': '4.8.0',
#                                             'tzdata': '2023.3',
#                                             'urllib3': '2.0.7',
#                                             'urwid': '2.2.3',
#                                             'urwid-readline': '0.13',
#                                             'virtualenv': '20.24.6',
#                                             'wcwidth': '0.2.9',
#                                             'yarg': '0.1.9'},
#                            based_on=[],
#                            labels={'dataset': '',
#                                    'datatype': 'annotation_file',
#                                    'description': '',
#                                    'infos': {'stratification': 'new cool '
#                                                                'method'},
#                                    'project': 'awesome-project',
#                                    'ticket': 'AB-123'},
#                            remote_root='/home/cgebbe/tmp/elliptio/2023/12/03/andy/134255_artifact_b4c31f3a-c25d-4dda-aa74-cab7245116f8',
#                            local_root='',
#                            file_relpaths=['train.txt', 'test.txt'],
#                            log_relpaths=[],
#                            version=1),
#          files={'test.txt': LocalFile(remote_url=PurePosixPath('/home/cgebbe/tmp/elliptio/2023/12/03/andy/134255_artifact_b4c31f3a-c25d-4dda-aa74-cab7245116f8/files/test.txt')),
#                 'train.txt': LocalFile(remote_url=PurePosixPath('/home/cgebbe/tmp/elliptio/2023/12/03/andy/134255_artifact_b4c31f3a-c25d-4dda-aa74-cab7245116f8/files/train.txt'))},
#          logs={})
#                   path   class
# 0  /path/to/image0.png       0
# 1  /path/to/image1.png       1

# %% [markdown]
# # Reproducability

# %% [markdown]
# Let's assume that she got an error upon opening the file. Could it be that Andy used another pandas version?

# %%
artifact.metadata.python_packages["pandas"]
# Out:
# '2.1.3'

# %% [markdown]
# Yes, Andy used `2.1.3.` whereas Brenda is using `1.4.0`. To be on the safe side, she quickly matches all her python libraries to the ones from Andy. She could also checkout the git commit hash as well as any local `git diff`erences (not yet implemented).
#
# After she successfully opened the file, she trains a model and saves it:

# %%
with eio.mock_username("brenda"):
    model = DummyModel()
    model.train(train_path=artifact.files["train.txt"].remote_url)
    with h.new(["model.pt"]) as new:
        model.save(new.file.remote_url)

# %% [markdown]
# ## Searching files by lineage

# %% [markdown]
# Once Andy comes back from his antarctica-crossing, he wants to know whether anybody actually used the newly stratified dataset he created:

# %%
h.find(query={"based_on": artifact_id})
# Out:
#                                                         creation_time  \
# artifact_id
# artifact_04312c0b-26a7-4f6d-8790-9c03bb7912b1 2023-12-03 13:43:08.551
#
#                                               username file_relpaths  \
# artifact_id
# artifact_04312c0b-26a7-4f6d-8790-9c03bb7912b1   brenda    [model.pt]
#
#                                                                                                                                                                                      argv  \
# artifact_id
# artifact_04312c0b-26a7-4f6d-8790-9c03bb7912b1  /home/cgebbe/venvs/elliptio/bin/python -m ipykernel_launcher --f=/home/cgebbe/.local/share/jupyter/runtime/kernel-v2-3296HzpU9aTlH5J3.json
#
#                                                                                       based_on  \
# artifact_id
# artifact_04312c0b-26a7-4f6d-8790-9c03bb7912b1  [artifact_b4c31f3a-c25d-4dda-aa74-cab7245116f8]
#
#                                               hostname  \
# artifact_id
# artifact_04312c0b-26a7-4f6d-8790-9c03bb7912b1   cgebbe
#
#                                                                                                                                      labels  \
# artifact_id
# artifact_04312c0b-26a7-4f6d-8790-9c03bb7912b1  {'datatype': '', 'ticket': '', 'project': '', 'dataset': '', 'description': '', 'infos': {}}
#
#                                               local_root log_relpaths  \
# artifact_id
# artifact_04312c0b-26a7-4f6d-8790-9c03bb7912b1                      []
#
#                                                                                                                                     remote_root  \
# artifact_id
# artifact_04312c0b-26a7-4f6d-8790-9c03bb7912b1  /home/cgebbe/tmp/elliptio/2023/12/03/brenda/134308_artifact_04312c0b-26a7-4f6d-8790-9c03bb7912b1
#
#                                                                                  run_id  \
# artifact_id
# artifact_04312c0b-26a7-4f6d-8790-9c03bb7912b1  run_2ea13cb6-61b9-41ef-82f7-b58acf119180
#
#                                                version
# artifact_id
# artifact_04312c0b-26a7-4f6d-8790-9c03bb7912b1        1

# %% [markdown]
# He's happy to see that Brenda continued his work and checks out whether his method lead to a better model (for example, by following the data lineage to the evaluation metrics generated by Charlie).
#
# Note that the lineage between `train.txt` and `model.pth` in Brendas run was tracked automatically. Every time `h.get(artifact_id)` is called, it's added to the `h.based_on` list.
